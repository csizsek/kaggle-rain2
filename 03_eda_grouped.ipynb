# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
from pylab import rcParams
# %pylab inline
rcParams['figure.figsize'] = 12, 6
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
s = pd.read_csv('tmp/grouped.csv').sample(20000)

# %%
tr = s[s.Expected != -1]
te = s[s.Expected == -1]

# %%
print len(tr)
print len(te)
# Out:
# 12569
# 7431

# %% [markdown]
# #Examine 'Expected'

# %%
tr.Expected.describe()
# Out:
# count    12569.000000
# mean       128.511632
# std        638.507388
# min          0.010000
# 25%          0.254000
# 50%          1.016000
# 75%          3.810002
# max      32783.290000
# Name: Expected, dtype: float64

# %%
top_q = tr.Expected.quantile(0.99)
_ = plt.hist(tr.Expected.values, bins=50, range=(0, top_q))

# %%
top_q = tr.Expected.quantile(0.99)
_ = plt.hist(tr.Expected.values, bins=50, range=(0, top_q))
plt.yscale('log', nonposy='clip')

# %%
cnt_t1 = tr.cnt.quantile(0.333)
cnt_t2 = tr.cnt.quantile(0.666)
e1 = tr[tr.cnt < cnt_t1].Expected.values
e2 = tr[(tr.cnt >= cnt_t1) & (tr.cnt < cnt_t2)].Expected.values
e3 = tr[tr.cnt >= cnt_t2].Expected.values
top_q = tr.Expected.quantile(0.99)
_ = plt.hist(e1, bins=30, range=(0, top_q), histtype='step')
_ = plt.hist(e2, bins=30, range=(0, top_q), histtype='step')
_ = plt.hist(e3, bins=30, range=(0, top_q), histtype='step')
plt.yscale('log', nonposy='clip')

# %%
_ = plt.scatter(tr.cnt.values, tr.Expected.values, marker='_')
plt.ylim(0, 30)
# Out:
# (0, 30)

# %%
_ = plt.scatter(tr.Ref_mean, tr.Expected.values, marker='.')
plt.ylim(0, 30)
# Out:
# (0, 30)

# %%
_ = plt.scatter(tr.radardist_km_mean, tr.Expected.values, marker='_')
plt.ylim(0, 30)
# Out:
# (0, 30)

# %%
_ = plt.scatter(tr.RefComposite_mean, tr.Expected.values, marker='.')
plt.ylim(0, 30)
# Out:
# (0, 30)

# %%
_ = plt.scatter(tr.RhoHV_mean, tr.Expected.values, marker='.')
plt.ylim(0, 30)
# Out:
# (0, 30)

# %%
_ = plt.scatter(tr.Zdr_mean, tr.Expected.values, marker='.')
plt.ylim(0, 30)
# Out:
# (0, 30)

# %%
_ = plt.scatter(tr.Kdp_mean, tr.Expected.values, marker='.')
plt.ylim(0, 30)
# Out:
# (0, 30)

# %%
limit = 30
print len(tr[tr.Expected >= limit])
tr[tr.Expected >= limit].Expected.value_counts().head()
# Out:
# 1311
# 166.37009     90
# 614.42633     82
# 151.38408     60
# 1106.42460    59
# 2945.13160    49
# dtype: int64
